# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
WORKING_DIR1  = "C:/Users/ASUS/Documents/GitHub/R5D5-Project/model/DataPreprocess/Datasets/2K20_ratings.csv"

# %%
df1 = pd.read_csv(WORKING_DIR1)

# %%
df1.head()
# Out:
#            Player  Close Shot  Mid-Range Shot  Three-Point Shot  Free Throw  \
# 0    Aaron Gordon          76              60                74          70
# 1      Al Horford          70              90                75          73
# 2  Andre Drummond          76              47                60          64
# 3  Andrew Wiggins          85              71                77          72
# 4   Anthony Davis          90              72                74          86
#
#    Shot IQ  Offensive Consistency  Speed  Acceleration  Strength  ...  \
# 0       97                     85     71            67        72  ...
# 1       86                     65     53            48        91  ...
# 2       62                     70     60            58        95  ...
# 3       66                     95     82            85        57  ...
# 4       90                     98     79            78        87  ...
#
#    Perimeter Defense  Steal  Block  Lateral Quickness  Help Defense IQ  \
# 0                 79     40     52                 74               75
# 1                 63     42     65                 67               92
# 2                 52     87     80                 52               84
# 3                 66     37     60                 82               72
# 4                 73     63     89                 71               97
#
#    Pass Perception  Defensive Consistency  Offensive Rebound  \
# 0               68                     70                 52
# 1               70                     90                 50
# 2               80                     75                 90
# 3               75                     55                 41
# 4               82                     95                 75
#
#    Defensive Rebound    salaries
# 0                 74  19863636.0
# 1                 68  28000000.0
# 2                 97  27093018.0
# 3                 56  27504630.0
# 4                 81  27093019.0
#
# [5 rows x 38 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Player                 100 non-null    object
#  1   Close Shot             100 non-null    int64
#  2   Mid-Range Shot         100 non-null    int64
#  3   Three-Point Shot       100 non-null    int64
#  4   Free Throw             100 non-null    int64
#  5   Shot IQ                100 non-null    int64
#  6   Offensive Consistency  100 non-null    int64
#  7   Speed                  100 non-null    int64
#  8   Acceleration           100 non-null    int64
#  9   Strength               100 non-null    int64
#  10  Vertical               100 non-null    int64
#  11  Stamina                100 non-null    int64
#  12  Hustle                 100 non-null    int64
#  13  Overall Durability     100 non-null    int64
#  14  Layup                  100 non-null    int64
#  15  Standing Dunk          100 non-null    int64
#  16  Driving Dunk           100 non-null    int64
#  17  Post Hook              100 non-null    int64
#  18  Post Fade              100 non-null    int64
#  19  Post Control           100 non-null    int64
#  20  Draw Foul              100 non-null    int64
#  21  Hands                  100 non-null    int64
#  22  Pass Accuracy          100 non-null    int64
#  23  Ball Handle            100 non-null    int64
#  24  Speed with Ball        100 non-null    int64
#  25  Pass IQ                100 non-null    int64
#  26  Pass Vision            100 non-null    int64
#  27  Interior Defense       100 non-null    int64
#  28  Perimeter Defense      100 non-null    int64
#  29  Steal                  100 non-null    int64
#  30  Block                  100 non-null    int64
#  31  Lateral Quickness      100 non-null    int64
#  32  Help Defense IQ        100 non-null    int64
#  33  Pass Perception        100 non-null    int64
#  34  Defensive Consistency  100 non-null    int64
#  35  Offensive Rebound      100 non-null    int64
#  36  Defensive Rebound      100 non-null    int64
#  37  salaries               87 non-null     float64
# dtypes: float64(1), int64(36), object(1)
# memory usage: 29.8+ KB

# %%
# Drop the "Player" column
df1.drop("Player", axis=1, inplace=True)

# %%
# Remove the rows that contain "#N/A" in the "salaries" column
df1.dropna(subset=["salaries"], inplace=True)

# %%
df1 = df1.rename(columns={'salaries':'salary'})

# %%
# Initialize the Scaler
scaler = MinMaxScaler()

# Fit and transform the scaler on the salary column
df1['salary'] = scaler.fit_transform(df1[['salary']])

# %%
df1.head()
# Out:
#    Close Shot  Mid-Range Shot  Three-Point Shot  Free Throw  Shot IQ  \
# 0          76              60                74          70       97
# 1          70              90                75          73       86
# 2          76              47                60          64       62
# 3          85              71                77          72       66
# 4          90              72                74          86       90
#
#    Offensive Consistency  Speed  Acceleration  Strength  Vertical  ...  \
# 0                     85     71            67        72        92  ...
# 1                     65     53            48        91        69  ...
# 2                     70     60            58        95        79  ...
# 3                     95     82            85        57        98  ...
# 4                     98     79            78        87        86  ...
#
#    Perimeter Defense  Steal  Block  Lateral Quickness  Help Defense IQ  \
# 0                 79     40     52                 74               75
# 1                 63     42     65                 67               92
# 2                 52     87     80                 52               84
# 3                 66     37     60                 82               72
# 4                 73     63     89                 71               97
#
#    Pass Perception  Defensive Consistency  Offensive Rebound  \
# 0               68                     70                 52
# 1               70                     90                 50
# 2               80                     75                 90
# 3               75                     55                 41
# 4               82                     95                 75
#
#    Defensive Rebound    salary
# 0                 74  0.473311
# 1                 68  0.683705
# 2                 97  0.660252
# 3                 56  0.670896
# 4                 81  0.660252
#
# [5 rows x 37 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87 entries, 0 to 99
# Data columns (total 37 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Close Shot             87 non-null     int64
#  1   Mid-Range Shot         87 non-null     int64
#  2   Three-Point Shot       87 non-null     int64
#  3   Free Throw             87 non-null     int64
#  4   Shot IQ                87 non-null     int64
#  5   Offensive Consistency  87 non-null     int64
#  6   Speed                  87 non-null     int64
#  7   Acceleration           87 non-null     int64
#  8   Strength               87 non-null     int64
#  9   Vertical               87 non-null     int64
#  10  Stamina                87 non-null     int64
#  11  Hustle                 87 non-null     int64
#  12  Overall Durability     87 non-null     int64
#  13  Layup                  87 non-null     int64
#  14  Standing Dunk          87 non-null     int64
#  15  Driving Dunk           87 non-null     int64
#  16  Post Hook              87 non-null     int64
#  17  Post Fade              87 non-null     int64
#  18  Post Control           87 non-null     int64
#  19  Draw Foul              87 non-null     int64
#  20  Hands                  87 non-null     int64
#  21  Pass Accuracy          87 non-null     int64
#  22  Ball Handle            87 non-null     int64
#  23  Speed with Ball        87 non-null     int64
#  24  Pass IQ                87 non-null     int64
#  25  Pass Vision            87 non-null     int64
#  26  Interior Defense       87 non-null     int64
#  27  Perimeter Defense      87 non-null     int64
#  28  Steal                  87 non-null     int64
#  29  Block                  87 non-null     int64
#  30  Lateral Quickness      87 non-null     int64
#  31  Help Defense IQ        87 non-null     int64
#  32  Pass Perception        87 non-null     int64
#  33  Defensive Consistency  87 non-null     int64
#  34  Offensive Rebound      87 non-null     int64
#  35  Defensive Rebound      87 non-null     int64
#  36  salary                 87 non-null     float64
# dtypes: float64(1), int64(36)
# memory usage: 25.8 KB

# %%
#graph view

# %%
df1.hist(bins=30,figsize=(20,15))
plt.show()

# %%
# linnear relationshp between each variable

# %%
df1.corr()
# Out:
#                        Close Shot  Mid-Range Shot  Three-Point Shot  \
# Close Shot               1.000000        0.309610          0.141160
# Mid-Range Shot           0.309610        1.000000          0.572105
# Three-Point Shot         0.141160        0.572105          1.000000
# Free Throw               0.184394        0.562700          0.697720
# Shot IQ                  0.175483        0.299279          0.069523
# Offensive Consistency    0.327166        0.347251          0.323547
# Speed                    0.020748        0.142292          0.399809
# Acceleration             0.047593        0.196277          0.503232
# Strength                 0.103153       -0.321855         -0.457087
# Vertical                -0.036966       -0.107359          0.069153
# Stamina                  0.108474        0.001788          0.305790
# Hustle                  -0.022411       -0.046247         -0.167051
# Overall Durability       0.007962        0.042539          0.135058
# Layup                    0.275798        0.257599          0.287466
# Standing Dunk            0.074136       -0.425698         -0.526833
# Driving Dunk             0.088674       -0.256672         -0.222518
# Post Hook                0.169982       -0.189171         -0.320851
# Post Fade                0.296522        0.068724          0.074718
# Post Control             0.278319       -0.134017         -0.226978
# Draw Foul                0.177901        0.075492          0.013466
# Hands                    0.228379        0.001503          0.206649
# Pass Accuracy            0.037162        0.374699          0.613484
# Ball Handle             -0.003520        0.330314          0.607775
# Speed with Ball          0.029992        0.244595          0.586345
# Pass IQ                  0.136331        0.281354          0.465003
# Pass Vision              0.157968        0.185312          0.363350
# Interior Defense         0.039573       -0.334431         -0.496761
# Perimeter Defense       -0.108567        0.153822          0.395540
# Steal                   -0.111900       -0.066186          0.081849
# Block                   -0.027470       -0.317973         -0.521251
# Lateral Quickness       -0.130445        0.173703          0.390908
# Help Defense IQ         -0.092462       -0.191361         -0.270215
# Pass Perception          0.019123        0.081354          0.139821
# Defensive Consistency   -0.143035       -0.170788         -0.227562
# Offensive Rebound        0.051683       -0.374153         -0.646546
# Defensive Rebound        0.142425       -0.253059         -0.469478
# salary                   0.144394        0.116810          0.207361
#
#                        Free Throw   Shot IQ  Offensive Consistency     Speed  \
# Close Shot               0.184394  0.175483               0.327166  0.020748
# Mid-Range Shot           0.562700  0.299279               0.347251  0.142292
# Three-Point Shot         0.697720  0.069523               0.323547  0.399809
# Free Throw               1.000000  0.144912               0.282986  0.256319
# Shot IQ                  0.144912  1.000000               0.733654  0.037875
# Offensive Consistency    0.282986  0.733654               1.000000  0.322784
# Speed                    0.256319  0.037875               0.322784  1.000000
# Acceleration             0.331418 -0.032255               0.302794  0.929126
# Strength                -0.452668 -0.030388              -0.191997 -0.448516
# Vertical                -0.061975 -0.058620               0.101367  0.584646
# Stamina                  0.109590  0.157453               0.366416  0.292257
# Hustle                  -0.232958  0.022614              -0.004285  0.075062
# Overall Durability      -0.028982  0.060609               0.075746  0.178281
# Layup                    0.184910  0.373078               0.624035  0.625517
# Standing Dunk           -0.557911  0.070406              -0.153277 -0.527383
# Driving Dunk            -0.359953  0.003559               0.019624  0.075983
# Post Hook               -0.336837  0.139802              -0.012900 -0.552652
# Post Fade               -0.013230  0.065219               0.093949 -0.246979
# Post Control            -0.231313  0.047234              -0.048230 -0.436495
# Draw Foul                0.041546  0.517455               0.640923  0.218060
# Hands                    0.122724  0.250214               0.293791  0.285527
# Pass Accuracy            0.526024  0.053094               0.276520  0.710140
# Ball Handle              0.512333  0.037586               0.327777  0.819642
# Speed with Ball          0.426920 -0.007833               0.317014  0.887453
# Pass IQ                  0.391126  0.116282               0.303407  0.508089
# Pass Vision              0.283928  0.080486               0.311542  0.608514
# Interior Defense        -0.455704 -0.009920              -0.277540 -0.526442
# Perimeter Defense        0.265832 -0.100436              -0.025282  0.650259
# Steal                    0.027290 -0.318201              -0.199846  0.355813
# Block                   -0.461986 -0.136101              -0.333410 -0.520610
# Lateral Quickness        0.246477 -0.071130               0.041356  0.741289
# Help Defense IQ         -0.292779 -0.142800              -0.345203 -0.178460
# Pass Perception          0.018170 -0.152173              -0.078959  0.399622
# Defensive Consistency   -0.212258 -0.115239              -0.334143 -0.011338
# Offensive Rebound       -0.616701 -0.000058              -0.182338 -0.488944
# Defensive Rebound       -0.445545  0.080672              -0.154921 -0.437815
# salary                   0.202932  0.088430               0.099242  0.117701
#
#                        Acceleration  Strength  Vertical  ...  \
# Close Shot                 0.047593  0.103153 -0.036966  ...
# Mid-Range Shot             0.196277 -0.321855 -0.107359  ...
# Three-Point Shot           0.503232 -0.457087  0.069153  ...
# Free Throw                 0.331418 -0.452668 -0.061975  ...
# Shot IQ                   -0.032255 -0.030388 -0.058620  ...
# Offensive Consistency      0.302794 -0.191997  0.101367  ...
# Speed                      0.929126 -0.448516  0.584646  ...
# Acceleration               1.000000 -0.532400  0.582360  ...
# Strength                  -0.532400  1.000000 -0.138955  ...
# Vertical                   0.582360 -0.138955  1.000000  ...
# Stamina                    0.317712  0.009893  0.313796  ...
# Hustle                     0.007185  0.324986  0.211598  ...
# Overall Durability         0.212868 -0.000179  0.303148  ...
# Layup                      0.615481 -0.278964  0.439815  ...
# Standing Dunk             -0.599823  0.771825 -0.108890  ...
# Driving Dunk               0.007659  0.441181  0.491974  ...
# Post Hook                 -0.609082  0.785438 -0.298140  ...
# Post Fade                 -0.255485  0.523671 -0.172632  ...
# Post Control              -0.480230  0.770662 -0.233388  ...
# Draw Foul                  0.175313  0.122533  0.086757  ...
# Hands                      0.210440  0.209637  0.088713  ...
# Pass Accuracy              0.745168 -0.599772  0.281232  ...
# Ball Handle                0.871870 -0.667146  0.442353  ...
# Speed with Ball            0.927702 -0.571433  0.520381  ...
# Pass IQ                    0.492320 -0.342563  0.116906  ...
# Pass Vision                0.613523 -0.357799  0.165904  ...
# Interior Defense          -0.596445  0.772466 -0.115518  ...
# Perimeter Defense          0.658893 -0.466268  0.365181  ...
# Steal                      0.333839 -0.139261  0.148417  ...
# Block                     -0.544097  0.553061 -0.135201  ...
# Lateral Quickness          0.729825 -0.539811  0.458739  ...
# Help Defense IQ           -0.213495  0.360852 -0.076131  ...
# Pass Perception            0.415588 -0.102750  0.273150  ...
# Defensive Consistency     -0.043283  0.141370  0.011980  ...
# Offensive Rebound         -0.588195  0.666938 -0.243783  ...
# Defensive Rebound         -0.546922  0.687504 -0.289633  ...
# salary                     0.097561  0.103418 -0.019428  ...
#
#                        Perimeter Defense     Steal     Block  \
# Close Shot                     -0.108567 -0.111900 -0.027470
# Mid-Range Shot                  0.153822 -0.066186 -0.317973
# Three-Point Shot                0.395540  0.081849 -0.521251
# Free Throw                      0.265832  0.027290 -0.461986
# Shot IQ                        -0.100436 -0.318201 -0.136101
# Offensive Consistency          -0.025282 -0.199846 -0.333410
# Speed                           0.650259  0.355813 -0.520610
# Acceleration                    0.658893  0.333839 -0.544097
# Strength                       -0.466268 -0.139261  0.553061
# Vertical                        0.365181  0.148417 -0.135201
# Stamina                         0.245942  0.016003 -0.183462
# Hustle                          0.030079  0.127130  0.136271
# Overall Durability              0.255818 -0.063502 -0.205015
# Layup                           0.422574  0.178298 -0.369866
# Standing Dunk                  -0.562987 -0.194772  0.696184
# Driving Dunk                   -0.002140  0.004264  0.268629
# Post Hook                      -0.578700 -0.193494  0.638918
# Post Fade                      -0.185680 -0.028074  0.368609
# Post Control                   -0.369510 -0.122513  0.491484
# Draw Foul                      -0.152936 -0.171125 -0.063705
# Hands                           0.130419  0.112661 -0.038748
# Pass Accuracy                   0.648613  0.301276 -0.703136
# Ball Handle                     0.717253  0.356845 -0.678676
# Speed with Ball                 0.764530  0.376052 -0.633684
# Pass IQ                         0.418320  0.241982 -0.555741
# Pass Vision                     0.436567  0.263616 -0.581092
# Interior Defense               -0.321507 -0.132934  0.681639
# Perimeter Defense               1.000000  0.487770 -0.432123
# Steal                           0.487770  1.000000 -0.047358
# Block                          -0.432123 -0.047358  1.000000
# Lateral Quickness               0.923862  0.414606 -0.513869
# Help Defense IQ                 0.318017  0.286883  0.465159
# Pass Perception                 0.737875  0.536670 -0.140221
# Defensive Consistency           0.511228  0.347492  0.255335
# Offensive Rebound              -0.593630 -0.109343  0.700806
# Defensive Rebound              -0.492771 -0.072445  0.611473
# salary                          0.271323 -0.054114 -0.097543
#
#                        Lateral Quickness  Help Defense IQ  Pass Perception  \
# Close Shot                     -0.130445        -0.092462         0.019123
# Mid-Range Shot                  0.173703        -0.191361         0.081354
# Three-Point Shot                0.390908        -0.270215         0.139821
# Free Throw                      0.246477        -0.292779         0.018170
# Shot IQ                        -0.071130        -0.142800        -0.152173
# Offensive Consistency           0.041356        -0.345203        -0.078959
# Speed                           0.741289        -0.178460         0.399622
# Acceleration                    0.729825        -0.213495         0.415588
# Strength                       -0.539811         0.360852        -0.102750
# Vertical                        0.458739        -0.076131         0.273150
# Stamina                         0.205436         0.026862         0.279631
# Hustle                          0.036946         0.312407         0.147345
# Overall Durability              0.271157         0.045949         0.311322
# Layup                           0.471091        -0.149551         0.379737
# Standing Dunk                  -0.617720         0.292519        -0.299981
# Driving Dunk                    0.014845         0.230222         0.073533
# Post Hook                      -0.669357         0.237049        -0.307873
# Post Fade                      -0.285440         0.267862         0.036777
# Post Control                   -0.469646         0.314249        -0.059925
# Draw Foul                      -0.152635        -0.211076        -0.081537
# Hands                           0.088874         0.032194         0.156202
# Pass Accuracy                   0.662814        -0.262460         0.417230
# Ball Handle                     0.766816        -0.282588         0.432558
# Speed with Ball                 0.803210        -0.188005         0.493022
# Pass IQ                         0.383397        -0.211618         0.343308
# Pass Vision                     0.437180        -0.184460         0.321087
# Interior Defense               -0.416477         0.519613        -0.060275
# Perimeter Defense               0.923862         0.318017         0.737875
# Steal                           0.414606         0.286883         0.536670
# Block                          -0.513869         0.465159        -0.140221
# Lateral Quickness               1.000000         0.157413         0.646576
# Help Defense IQ                 0.157413         1.000000         0.517398
# Pass Perception                 0.646576         0.517398         1.000000
# Defensive Consistency           0.370256         0.822779         0.589187
# Offensive Rebound              -0.596237         0.242018        -0.289495
# Defensive Rebound              -0.530504         0.299389        -0.250090
# salary                          0.211296         0.230132         0.370967
#
#                        Defensive Consistency  Offensive Rebound  \
# Close Shot                         -0.143035           0.051683
# Mid-Range Shot                     -0.170788          -0.374153
# Three-Point Shot                   -0.227562          -0.646546
# Free Throw                         -0.212258          -0.616701
# Shot IQ                            -0.115239          -0.000058
# Offensive Consistency              -0.334143          -0.182338
# Speed                              -0.011338          -0.488944
# Acceleration                       -0.043283          -0.588195
# Strength                            0.141370           0.666938
# Vertical                            0.011980          -0.243783
# Stamina                             0.031596          -0.262416
# Hustle                              0.175208           0.250501
# Overall Durability                  0.076721          -0.157133
# Layup                              -0.032578          -0.348728
# Standing Dunk                       0.063595           0.789427
# Driving Dunk                        0.179792           0.278055
# Post Hook                          -0.035433           0.698411
# Post Fade                           0.038107           0.251529
# Post Control                        0.113862           0.531126
# Draw Foul                          -0.247539           0.090001
# Hands                               0.011249          -0.015604
# Pass Accuracy                      -0.111799          -0.708582
# Ball Handle                        -0.078859          -0.753870
# Speed with Ball                     0.001848          -0.690844
# Pass IQ                            -0.107794          -0.516921
# Pass Vision                        -0.136036          -0.454004
# Interior Defense                    0.333108           0.676652
# Perimeter Defense                   0.511228          -0.593630
# Steal                               0.347492          -0.109343
# Block                               0.255335           0.700806
# Lateral Quickness                   0.370256          -0.596237
# Help Defense IQ                     0.822779           0.242018
# Pass Perception                     0.589187          -0.289495
# Defensive Consistency               1.000000           0.063147
# Offensive Rebound                   0.063147           1.000000
# Defensive Rebound                   0.083210           0.824568
# salary                              0.243184          -0.180384
#
#                        Defensive Rebound    salary
# Close Shot                      0.142425  0.144394
# Mid-Range Shot                 -0.253059  0.116810
# Three-Point Shot               -0.469478  0.207361
# Free Throw                     -0.445545  0.202932
# Shot IQ                         0.080672  0.088430
# Offensive Consistency          -0.154921  0.099242
# Speed                          -0.437815  0.117701
# Acceleration                   -0.546922  0.097561
# Strength                        0.687504  0.103418
# Vertical                       -0.289633 -0.019428
# Stamina                        -0.206575  0.328705
# Hustle                          0.184852  0.135124
# Overall Durability             -0.070447  0.268734
# Layup                          -0.310705  0.288822
# Standing Dunk                   0.805223 -0.160546
# Driving Dunk                    0.335502  0.002464
# Post Hook                       0.759754 -0.024392
# Post Fade                       0.423592  0.276097
# Post Control                    0.686858  0.185734
# Draw Foul                       0.130598  0.039104
# Hands                           0.198893  0.427414
# Pass Accuracy                  -0.644100  0.282740
# Ball Handle                    -0.669759  0.183910
# Speed with Ball                -0.619751  0.199792
# Pass IQ                        -0.472960  0.327937
# Pass Vision                    -0.374700  0.285175
# Interior Defense                0.712257 -0.018349
# Perimeter Defense              -0.492771  0.271323
# Steal                          -0.072445 -0.054114
# Block                           0.611473 -0.097543
# Lateral Quickness              -0.530504  0.211296
# Help Defense IQ                 0.299389  0.230132
# Pass Perception                -0.250090  0.370967
# Defensive Consistency           0.083210  0.243184
# Offensive Rebound               0.824568 -0.180384
# Defensive Rebound               1.000000 -0.038566
# salary                         -0.038566  1.000000
#
# [37 rows x 37 columns]

# %%
# show what variable impacts salary the most

# %%
# Finding the useful features to predict the salary
corre = df1.corr()
corre['salary'].sort_values(ascending=False)
# Out:
# salary                   1.000000
# Hands                    0.427414
# Pass Perception          0.370967
# Stamina                  0.328705
# Pass IQ                  0.327937
# Layup                    0.288822
# Pass Vision              0.285175
# Pass Accuracy            0.282740
# Post Fade                0.276097
# Perimeter Defense        0.271323
# Overall Durability       0.268734
# Defensive Consistency    0.243184
# Help Defense IQ          0.230132
# Lateral Quickness        0.211296
# Three-Point Shot         0.207361
# Free Throw               0.202932
# Speed with Ball          0.199792
# Post Control             0.185734
# Ball Handle              0.183910
# Close Shot               0.144394
# Hustle                   0.135124
# Speed                    0.117701
# Mid-Range Shot           0.116810
# Strength                 0.103418
# Offensive Consistency    0.099242
# Acceleration             0.097561
# Shot IQ                  0.088430
# Draw Foul                0.039104
# Driving Dunk             0.002464
# Interior Defense        -0.018349
# Vertical                -0.019428
# Post Hook               -0.024392
# Defensive Rebound       -0.038566
# Steal                   -0.054114
# Block                   -0.097543
# Standing Dunk           -0.160546
# Offensive Rebound       -0.180384
# Name: salary, dtype: float64

# %%
# devide dataset into train and test

# %%
X = df1.drop('salary', axis=1)
y = df1['salary']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#exporting to csv file optional
df1.to_csv("ML_Model_Dataset_01/complete_data_model_2k_ratings.csv", index=False)
X_train.to_csv("ML_Model_Dataset_01/X_train02.csv", index=False)
X_test.to_csv("ML_Model_Dataset_01/X_test02.csv", index=False)
y_train.to_csv("ML_Model_Dataset_01/y_train02.csv", index=False)
y_test.to_csv("ML_Model_Dataset_01/y_test02.csv", index=False)
