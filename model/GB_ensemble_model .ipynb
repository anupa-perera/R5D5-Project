# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingRegressor, VotingRegressor
from sklearn.model_selection import train_test_split

# %%
# Load the three datasets
data1 = pd.read_csv("C:/Users/user/Documents/GitHub/R5D5-Project/model/ML_Model_Dataset_01/complete_data_model_nba2k_main_data_sheet.csv")
data2 = pd.read_csv("C:/Users/user/Documents/GitHub/R5D5-Project/model/ML_Model_Dataset_02/complete_data_model_2k_ratings.csv")
data3 = pd.read_csv("C:/Users/user/Documents/GitHub/R5D5-Project/model/ML_Model_Dataset_03/complete_data_model_NBA_Player_Stats_Playoffs.csv")
data4 = pd.read_csv("C:/Users/user/Documents/GitHub/R5D5-Project/model/ML_Model_Dataset_04/complete_data_model_NBA_Player_Stats_Regular.csv")

# %%
# Find the common features across all datasets
common_features = set(data1.columns).intersection(set(data2.columns)).intersection(set(data3.columns)).intersection(set(data4.columns))
target = 'salary'

# %%
# Split each dataset into training and validation sets
X1_train, X1_val, y1_train, y1_val = train_test_split(data1[features1], data1[target], test_size=0.2, random_state=42)
X2_train, X2_val, y2_train, y2_val = train_test_split(data2[features2], data2[target], test_size=0.2, random_state=42)
X3_train, X3_val, y3_train, y3_val = train_test_split(data3[features3], data3[target], test_size=0.2, random_state=42)
X4_train, X4_val, y4_train, y4_val = train_test_split(data4[features4], data4[target], test_size=0.2, random_state=42)

# %%
# Train a Gradient Boosting Regressor on each dataset with its best hyperparameters
gb1 = GradientBoostingRegressor(learning_rate=0.01, max_depth=2, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=417, subsample=1.0, random_state=42)
gb2 = GradientBoostingRegressor(learning_rate=0.1, max_depth=6, max_features='sqrt', min_samples_leaf=4, min_samples_split=8, n_estimators=323, subsample=0.7625340972035156, random_state=42)
gb3 = GradientBoostingRegressor(learning_rate=0.01, max_depth=6, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=225, subsample=0.8204906329264618, random_state=42)
gb4 = GradientBoostingRegressor(learning_rate=0.01, max_depth=6, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=500, subsample=0.5, random_state=42)

# %%
# Fit each model to its respective dataset
gb1.fit(X1_train, y1_train)
gb2.fit(X2_train, y2_train)
gb3.fit(X3_train, y3_train)
gb4.fit(X4_train, y4_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.01, max_depth=6, n_estimators=500,
#                           random_state=42, subsample=0.5)

# %%
# Combine the three models into an ensemble model
ensemble = VotingRegressor(estimators=[('gb1', gb1), ('gb2', gb2), ('gb3', gb3), ('gb4', gb4)])

# %%
ensemble.fit(X_val, y_val)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_34716\1869473121.py in <module>
# ----> 1 ensemble.fit(X_val, y_val)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_voting.py in fit(self, X, y, sample_weight)
#     527         """
#     528         y = column_or_1d(y, warn=True)
# --> 529         return super().fit(X, y, sample_weight)
#     530
#     531     def predict(self, X):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_voting.py in fit(self, X, y, sample_weight)
#      72             )
#      73
# ---> 74         self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#      75             delayed(_fit_single_estimator)(
#      76                 clone(clf),
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1041             # remaining jobs.
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_34716\638250339.py in <module>
# ----> 1 ensemble.fit(X_val, y_val)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_voting.py in fit(self, X, y, sample_weight)
#     527         """
#     528         y = column_or_1d(y, warn=True)
# --> 529         return super().fit(X, y, sample_weight)
#     530
#     531     def predict(self, X):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_voting.py in fit(self, X, y, sample_weight)
#      72             )
#      73
# ---> 74         self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#      75             delayed(_fit_single_estimator)(
#      76                 clone(clf),
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1041             # remaining jobs.
# ...
